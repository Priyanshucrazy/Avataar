# %%
# !pip install torch diffusers transformers accelerate rembg
# Out:
# Collecting torch
#   Downloading torch-2.4.1-cp311-cp311-win_amd64.whl.metadata (27 kB)
# Collecting diffusers
#   Downloading diffusers-0.30.3-py3-none-any.whl.metadata (18 kB)
# Collecting transformers
#   Downloading transformers-4.45.1-py3-none-any.whl.metadata (44 kB)
#      ---------------------------------------- 0.0/44.4 kB ? eta -:--:--
#      ---------------------------------------- 44.4/44.4 kB 2.1 MB/s eta 0:00:00
# Collecting accelerate
#   Downloading accelerate-0.34.2-py3-none-any.whl.metadata (19 kB)
# Collecting rembg
#   Downloading rembg-2.0.59-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: filelock in c:\users\asus\anaconda3\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\asus\anaconda3\lib\site-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in c:\users\asus\anaconda3\lib\site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in c:\users\asus\anaconda3\lib\site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in c:\users\asus\anaconda3\lib\site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\asus\anaconda3\lib\site-packages (from torch) (2023.10.0)
# Requirement already satisfied: importlib-metadata in c:\users\asus\anaconda3\lib\site-packages (from diffusers) (7.0.1)
# Collecting huggingface-hub>=0.23.2 (from diffusers)
#   Downloading huggingface_hub-0.25.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy in c:\users\asus\anaconda3\lib\site-packages (from diffusers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\asus\anaconda3\lib\site-packages (from diffusers) (2023.10.3)
# Requirement already satisfied: requests in c:\users\asus\anaconda3\lib\site-packages (from diffusers) (2.31.0)
# Collecting safetensors>=0.3.1 (from diffusers)
#   Downloading safetensors-0.4.5-cp311-none-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: Pillow in c:\users\asus\anaconda3\lib\site-packages (from diffusers) (10.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\asus\anaconda3\lib\site-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\asus\anaconda3\lib\site-packages (from transformers) (6.0.1)
# Collecting tokenizers<0.21,>=0.20 (from transformers)
#   Downloading tokenizers-0.20.0-cp311-none-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: tqdm>=4.27 in c:\users\asus\anaconda3\lib\site-packages (from transformers) (4.65.0)
# Requirement already satisfied: psutil in c:\users\asus\anaconda3\lib\site-packages (from accelerate) (5.9.0)
# Requirement already satisfied: jsonschema in c:\users\asus\anaconda3\lib\site-packages (from rembg) (4.19.2)
# Collecting onnxruntime (from rembg)
#   Downloading onnxruntime-1.19.2-cp311-cp311-win_amd64.whl.metadata (4.7 kB)
# Collecting opencv-python-headless (from rembg)
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting pooch (from rembg)
#   Downloading pooch-1.8.2-py3-none-any.whl.metadata (10 kB)
# Collecting pymatting (from rembg)
#   Downloading PyMatting-1.1.12-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: scikit-image in c:\users\asus\anaconda3\lib\site-packages (from rembg) (0.22.0)
# Requirement already satisfied: scipy in c:\users\asus\anaconda3\lib\site-packages (from rembg) (1.11.4)
# Requirement already satisfied: colorama in c:\users\asus\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in c:\users\asus\anaconda3\lib\site-packages (from importlib-metadata->diffusers) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\asus\anaconda3\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\asus\anaconda3\lib\site-packages (from jsonschema->rembg) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\asus\anaconda3\lib\site-packages (from jsonschema->rembg) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\asus\anaconda3\lib\site-packages (from jsonschema->rembg) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\asus\anaconda3\lib\site-packages (from jsonschema->rembg) (0.10.6)
# Collecting coloredlogs (from onnxruntime->rembg)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in c:\users\asus\anaconda3\lib\site-packages (from onnxruntime->rembg) (24.3.25)
# Requirement already satisfied: protobuf in c:\users\asus\anaconda3\lib\site-packages (from onnxruntime->rembg) (3.20.3)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\asus\anaconda3\lib\site-packages (from pooch->rembg) (3.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\asus\anaconda3\lib\site-packages (from requests->diffusers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\anaconda3\lib\site-packages (from requests->diffusers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus\anaconda3\lib\site-packages (from requests->diffusers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\anaconda3\lib\site-packages (from requests->diffusers) (2024.7.4)
# Requirement already satisfied: numba!=0.49.0 in c:\users\asus\anaconda3\lib\site-packages (from pymatting->rembg) (0.59.0)
# Requirement already satisfied: imageio>=2.27 in c:\users\asus\anaconda3\lib\site-packages (from scikit-image->rembg) (2.33.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\asus\anaconda3\lib\site-packages (from scikit-image->rembg) (2023.4.12)
# Requirement already satisfied: lazy_loader>=0.3 in c:\users\asus\anaconda3\lib\site-packages (from scikit-image->rembg) (0.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\asus\anaconda3\lib\site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\users\asus\anaconda3\lib\site-packages (from numba!=0.49.0->pymatting->rembg) (0.42.0)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime->rembg)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Collecting pyreadline3 (from humanfriendly>=9.1->coloredlogs->onnxruntime->rembg)
#   Downloading pyreadline3-3.5.4-py3-none-any.whl.metadata (4.7 kB)
# Downloading torch-2.4.1-cp311-cp311-win_amd64.whl (199.4 MB)
#    ---------------------------------------- 0.0/199.4 MB ? eta -:--:--
#    ---------------------------------------- 0.3/199.4 MB 7.0 MB/s eta 0:00:29
#    ---------------------------------------- 0.8/199.4 MB 8.1 MB/s eta 0:00:25
#    ---------------------------------------- 1.3/199.4 MB 9.1 MB/s eta 0:00:22
#    ---------------------------------------- 1.9/199.4 MB 10.2 MB/s eta 0:00:20
#     --------------------------------------- 2.7/199.4 MB 11.5 MB/s eta 0:00:18
#     --------------------------------------- 3.6/199.4 MB 12.9 MB/s eta 0:00:16
#     --------------------------------------- 4.8/199.4 MB 14.6 MB/s eta 0:00:14
#    - -------------------------------------- 5.9/199.4 MB 16.4 MB/s eta 0:00:12
#    - -------------------------------------- 7.1/199.4 MB 16.7 MB/s eta 0:00:12
#    - -------------------------------------- 7.8/199.4 MB 17.1 MB/s eta 0:00:12
#    - -------------------------------------- 8.2/199.4 MB 15.9 MB/s eta 0:00:13
#    - -------------------------------------- 8.3/199.4 MB 15.1 MB/s eta 0:00:13
#    - -------------------------------------- 8.5/199.4 MB 13.9 MB/s eta 0:00:14
#    - -------------------------------------- 8.8/199.4 MB 13.4 MB/s eta 0:00:15
#    - -------------------------------------- 9.0/199.4 MB 12.8 MB/s eta 0:00:15
#    - -------------------------------------- 9.3/199.4 MB 12.4 MB/s eta 0:00:16
#    - -------------------------------------- 9.6/199.4 MB 12.1 MB/s eta 0:00:16
#    - -------------------------------------- 9.9/199.4 MB 11.8 MB/s eta 0:00:17
#    -- ------------------------------------- 10.2/199.4 MB 11.7 MB/s eta 0:00:17
#    -- ------------------------------------- 10.6/199.4 MB 11.5 MB/s eta 0:00:17
#    -- -------------------------------------
MB/s eta 0:00:02
#    --------------------------- ------------ 26.5/38.8 MB 12.6 MB/s eta 0:00:01
#    --------------------------- ------------ 27.1/38.8 MB 12.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 27.7/38.8 MB 12.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 28.3/38.8 MB 11.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 28.9/38.8 MB 11.7 MB/s eta 0:00:01
#    ------------------------------ --------- 29.5/38.8 MB 11.5 MB/s eta 0:00:01
#    ------------------------------- -------- 30.1/38.8 MB 11.5 MB/s eta 0:00:01
#    ------------------------------- -------- 30.8/38.8 MB 11.9 MB/s eta 0:00:01
#    -------------------------------- ------- 31.5/38.8 MB 12.1 MB/s eta 0:00:01
#    --------------------------------- ------ 32.2/38.8 MB 12.6 MB/s eta 0:00:01
#    --------------------------------- ------ 32.8/38.8 MB 12.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 33.6/38.8 MB 13.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 34.3/38.8 MB 13.4 MB/s eta 0:00:01
#    ------------------------------------ --- 35.0/38.8 MB 13.6 MB/s eta 0:00:01
#    ------------------------------------ --- 35.7/38.8 MB 13.9 MB/s eta 0:00:01
#    ------------------------------------- -- 36.5/38.8 MB 14.2 MB/s eta 0:00:01
#    -------------------------------------- - 37.2/38.8 MB 14.6 MB/s eta 0:00:01
#    ---------------------------------------  38.0/38.8 MB 14.9 MB/s eta 0:00:01
#    ---------------------------------------  38.7/38.8 MB 15.6 MB/s eta 0:00:01
#    ---------------------------------------  38.7/38.8 MB 15.6 MB/s eta 0:00:01
#    ---------------------------------------- 38.8/38.8 MB 13.9 MB/s eta 0:00:00
# Downloading pooch-1.8.2-py3-none-any.whl (64 kB)
#    ---------------------------------------- 0.0/64.6 kB ? eta -:--:--
#    ---------------------------------------- 64.6/64.6 kB 3.4 MB/s eta 0:00:00
# Downloading PyMatting-1.1.12-py3-none-any.whl (52 kB)
#    ---------------------------------------- 0.0/53.0 kB ? eta -:--:--
#    ---------------------------------------- 53.0/53.0 kB ? eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ---------------------------------------- 0.0/46.0 kB ? eta -:--:--
#    ---------------------------------------- 46.0/46.0 kB 2.4 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#    ---------------------------------------- 86.8/86.8 kB 4.8 MB/s eta 0:00:00
# Downloading pyreadline3-3.5.4-py3-none-any.whl (83 kB)
#    ---------------------------------------- 0.0/83.2 kB ? eta -:--:--
#    ---------------------------------------- 83.2/83.2 kB ? eta 0:00:00
# Installing collected packages: safetensors, pyreadline3, opencv-python-headless, torch, pymatting, pooch, humanfriendly, huggingface-hub, tokenizers, diffusers, coloredlogs, accelerate, transformers, onnxruntime, rembg
# Successfully installed accelerate-0.34.2 coloredlogs-15.0.1 diffusers-0.30.3 huggingface-hub-0.25.1 humanfriendly-10.0 onnxruntime-1.19.2 opencv-python-headless-4.10.0.84 pooch-1.8.2 pymatting-1.1.12 pyreadline3-3.5.4 rembg-2.0.59 safetensors-0.4.5 tokenizers-0.20.0 torch-2.4.1 transformers-4.45.1

# %%
# Suppress warnings
import os
import warnings
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'  # Suppress TensorFlow logging
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=UserWarning)
os.environ['HF_HUB_DISABLE_SYMLINKS_WARNING'] = '1'

# Import required packages
import torch
import numpy as np
from diffusers import StableDiffusionInpaintPipeline
from PIL import Image
from rembg import remove
import matplotlib.pyplot as plt

def load_image(image_path):
    try:
        return Image.open(image_path).convert("RGB")
    except Exception as e:
        print(f"Error loading image: {str(e)}")
        return None

def remove_background(image):
    try:
        return remove(image)
    except Exception as e:
        print(f"Error removing background: {str(e)}")
        return image

def create_mask(image):
    # Convert to RGBA if it's not already
    image = image.convert("RGBA")
    
    # Get the alpha channel
    alpha = np.array(image)[:, :, 3]
    
    # Create mask: white (255) for transparent areas, black (0) for the object
    mask = Image.fromarray((alpha == 0).astype(np.uint8) * 255)
    
    # Display alpha channel and mask for debugging
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))
    ax1.imshow(alpha, cmap='gray')
    ax1.set_title("Alpha Channel")
    ax1.axis('off')
    ax2.imshow(mask, cmap='gray')
    ax2.set_title("Created Mask")
    ax2.axis('off')
    plt.show()
    
    return mask.convert("RGB")

def preprocess_image(image, target_size):
    # Resize image
    ratio = min(target_size[0] / image.width, target_size[1] / image.height)
    new_size = (int(image.width * ratio), int(image.height * ratio))
    image = image.resize(new_size, Image.LANCZOS)
    
    # Create a new image with an alpha channel
    new_image = Image.new("RGBA", target_size, (255, 255, 255, 0))
    
    # Paste the resized image onto the center of the transparent background
    paste_position = ((target_size[0] - new_size[0]) // 2, (target_size[1] - new_size[1]) // 2)
    new_image.paste(image, paste_position, image if image.mode == 'RGBA' else None)
    
    return new_image

def place_object_in_scene(image_path, text_prompt):
    # Load the pre-trained model
    pipe = StableDiffusionInpaintPipeline.from_pretrained(
        "stabilityai/stable-diffusion-2-inpainting",
        torch_dtype=torch.float16 if torch.cuda.is_available() else torch.float32,
    ).to("cuda" if torch.cuda.is_available() else "cpu")

    # Load and preprocess the input image
    input_image = load_image(image_path)
    if input_image is None:
        return None

    input_image_nobg = remove_background(input_image)
    
    # Preprocess images to 512x512
    input_image_nobg = preprocess_image(input_image_nobg, (512, 512))
    mask_image = create_mask(input_image_nobg)

    # Save intermediate images
    input_image.save("original_image.png")
    input_image_nobg.save("no_background_image.png")
    mask_image.save("mask_image.png")

    # Display original and preprocessed images
    fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 5))
    ax1.imshow(input_image)
    ax1.set_title("Original Image")
    ax1.axis('off')
    ax2.imshow(input_image_nobg)
    ax2.set_title("Background Removed")
    ax2.axis('off')
    ax3.imshow(mask_image)
    ax3.set_title("Mask")
    ax3.axis('off')
    plt.show()

    # Generate the image
    output_image = pipe(
        prompt=text_prompt,
        image=input_image_nobg.convert("RGB"),
        mask_image=mask_image,
        guidance_scale=7.5,
        num_inference_steps=50,
    ).images[0]

    # Save the generated image
    output_image.save("generated_image.png")

    # Display the generated image
    plt.figure(figsize=(10, 10))
    plt.imshow(output_image)
    plt.title("Generated Image")
    plt.axis('off')
    plt.show()

    return output_image

# Example usage
image_path = r"C:\Users\asus\Downloads\example1.jpg"  # Using raw string for Windows path
text_prompt = "product in a kitchen used in meal generation"

try:
    generated_image = place_object_in_scene(image_path, text_prompt)
    if generated_image is not None:
        print("Generated image saved as generated_image.png")
    else:
        print("Failed to generate image.")
except Exception as e:
    print(f"An error occurred: {str(e)}")
    print("Please check your image path and ensure you have a stable internet connection.")
# Out:
# Loading pipeline components...:   0%|          | 0/6 [00:00<?, ?it/s]
# C:\Users\asus\anaconda3\Lib\site-packages\transformers\tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generated image saved as generated_image.png

# %%
--user 
# !pip install opencv-python
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 --user
#       2 get_ipython().system('pip install opencv-python')
#
# NameError: name 'user' is not defined

# %%
import cv2
def generate_video_frames(image_path, text_prompt, num_frames=30, movement='zoom_out'):
    frames = []
    
    if movement == 'zoom_out':
        scales = np.linspace(1.0, 0.5, num_frames)
        positions = [(0, 0)] * num_frames
    elif movement == 'translate':
        scales = [1.0] * num_frames
        positions = [(int(i * 5), int(i * 5)) for i in range(num_frames)]
    else:
        raise ValueError("Unsupported movement type")
    
    for i in range(num_frames):
        frame = place_object_in_scene(image_path, text_prompt, positions[i], scales[i])
        frames.append(np.array(frame))
    
    return frames

def create_video(frames, output_path, fps=10):
    height, width, layers = frames[0].shape
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    video = cv2.VideoWriter(output_path, fourcc, fps, (width, height))
    
    for frame in frames:
        video.write(cv2.cvtColor(frame, cv2.COLOR_RGB2BGR))
    
    video.release()

def main(image_path, text_prompt, output_path, movement='zoom_out'):
    frames = generate_video_frames(image_path, text_prompt, movement=movement)
    create_video(frames, output_path)
    print(f"Video saved to {output_path}")

if __name__ == "__main__":
    import sys
    import argparse
    
    if 'ipykernel' in sys.modules:
        # We're in a Jupyter notebook or IPython environment
        print("Running in Jupyter/IPython environment. Use the run_in_notebook function.")
    else:
        # We're running as a standalone script
        parser = argparse.ArgumentParser(description="Generate a video from an object image and text prompt")
        parser.add_argument("--image", required=True, help="Path to the input image")
        parser.add_argument("--text-prompt", required=True, help="Text prompt for scene generation")
        parser.add_argument("--output", required=True, help="Path to save the output video")
        parser.add_argument("--movement", choices=['zoom_out', 'translate'], default='zoom_out', help="Type of movement in the video")
        
        args = parser.parse_args()
        
        main(args.image, args.text_prompt, args.output, args.movement)

# Function for Jupyter/IPython usage
def run_in_notebook(image_path, text_prompt, output_path, movement='zoom_out'):
    main(image_path, text_prompt, output_path, movement)
# Out:
# Running in Jupyter/IPython environment. Use the run_in_notebook function.
